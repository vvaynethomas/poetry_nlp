# %%
import pickle
import gensim
import numpy as np
import pandas as pd

# %%
# get dataframe and load model
with open('clean_line_df.pkl', 'rb') as f:
    clean_line_df = pickle.load(f)
    
doc2vec_model = gensim.models.doc2vec.Doc2Vec.load("poem_doc2vec_dbow2000.pkl")

# %%
lines = clean_line_df.words.to_list()

# %%
print(lines[0:5])
# Out:
# [['philosophic'], ['in', 'its', 'complex', 'ovoid', 'emptiness'], ['a', 'skillful', 'pundit', 'coined', 'it', 'as', 'a', 'sort'], ['of', 'stopgap', 'doorstop', 'for', 'those'], ['quaint', 'equations']]

# %%
lines_vector=[]

t = 50000

for i in range(len(lines)):
    if i % t == 0:
        print("line", i, ":", lines[i])
        print("***")
    line = lines[i]
    lines_vector.append(doc2vec_model.infer_vector(line))
    
#save the lines_vector
lines_vector_file = "lines_vector_500_a001_ma001_s10000.pkl"
with open('line_vectors', 'wb') as f:
    pickle.dump((lines_vector), f)
# Out:
# line 0 : ['philosophic']
# ***
# line 50000 : ['and', 'placid', 'blank', 'as', 'a', 'lake']
# ***
# line 100000 : ['stupidity', 'secrecy']
# ***
# line 150000 : ['and', 'swore', 'this', 'mare', 'was', 'far', 'more', 'worth']
# ***
# line 200000 : ['and', 'have', 'kept', 'their', 'lives', 'and', 'their', 'wives', 'and', 'their', 'children', 'and']
# ***
# line 250000 : ['fancy', 'this']
# ***
# line 300000 : ['here', 'is', 'my', 'hand']
# ***
# line 350000 : ['and', 'he', 'whose', 'soul', 'is', 'flat—the', 'sky']
# ***
# line 400000 : ['the', 'moral', 'of', 'the', 'story', 'was', 'plain', 'enough']
# ***
# line 450000 : ['the', 'cars', 'moved', 'down', 'the', 'street', 'slowly', 'as', 'always', 'so', 'many']
# ***

# %%
n_sequenced_lines = 6
v_dim = 2000

lines_label = [str(i) for i in range(len(lines))]
X_train = np.zeros((len(lines), n_sequenced_lines, v_dim), dtype=np.float)
y_train = np.zeros((len(lines), v_dim), dtype=np.float)


t = 10000
for i in range(len(lines_label)-n_sequenced_lines-1):
    if i % t == 0: print("new sequence: ", i)
    
    for k in range(n_sequenced_lines):
        line = lines_label[i+k]
        vect = lines_vector[i+k]
        
        if i % t == 0:
            print("  ", k + 1 ,"th vector for this sequence. line ", line, "(vector dim = ", len(vect), ")")
            
        for j in range(len(vect)):
            X_train[i, k, j] = vect[j]
    
    line_target = lines_label[i+n_sequenced_lines]
    v_target = lines_vector[i+n_sequenced_lines]
    if i % t == 0: print("  y vector for sequence ", line_target, ": (vector dim = ", len(v_target), ")")
    for j in range(len(v_target)):
        y_train[i, j] = v_target[j]

print(X_train.shape, y_train.shape)
# Out:
# new sequence:  0
#    1 th vector for this sequence. Sentence  0 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  1 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  2 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  3 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  4 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  5 (vector dim =  2000 )
#   y vector for this sequence  6 : (vector dim =  2000 )
# new sequence:  1000
#    1 th vector for this sequence. Sentence  1000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  1001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  1002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  1003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  1004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  1005 (vector dim =  2000 )
#   y vector for this sequence  1006 : (vector dim =  2000 )
# new sequence:  2000
#    1 th vector for this sequence. Sentence  2000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  2001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  2002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  2003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  2004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  2005 (vector dim =  2000 )
#   y vector for this sequence  2006 : (vector dim =  2000 )
# new sequence:  3000
#    1 th vector for this sequence. Sentence  3000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  3001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  3002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  3003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  3004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  3005 (vector dim =  2000 )
#   y vector for this sequence  3006 : (vector dim =  2000 )
# new sequence:  4000
#    1 th vector for this sequence. Sentence  4000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  4001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  4002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  4003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  4004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  4005 (vector dim =  2000 )
#   y vector for this sequence  4006 : (vector dim =  2000 )
# new sequence:  5000
#    1 th vector for this sequence. Sentence  5000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  5001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  5002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  5003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  5004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  5005 (vector dim =  2000 )
#   y vector for this sequence  5006 : (vector dim =  2000 )
# new sequence:  6000
#    1 th vector for this sequence. Sentence  6000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  6001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  6002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  6003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  6004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  6005 (vector dim =  2000 )
#   y vector for this sequence  6006 : (vector dim =  2000 )
# new sequence:  7000
#    1 th vector for this sequence. Sentence  7000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  7001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  7002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  7003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  7004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  7005 (vector dim =  2000 )
#   y vector for this sequence  7006 : (vector dim =  2000 )
# new sequence:  8000
#    1 th vector for this sequence. Sentence  8000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  8001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  8002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  8003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  8004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  8005 (vector dim =  2000 )
#   y vector for this sequence  8006 : (vector dim =  2000 )
# new sequence:  9000
#    1 th vector for this sequence. Sentence  9000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  9001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  9002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  9003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  9004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  9005 (vector dim =  2000 )
#   y vector for this sequence  9006 : (vector dim =  2000 )
# new sequence:  10000
#    1 th vector for this sequence. Sentence  10000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  10001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  10002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  10003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  10004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  10005 (vector dim =  2000 )
#   y vector for this sequence  10006 : (vector dim =  2000 )
# new sequence:  11000
#    1 th vector for this sequence. Sentence  11000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  11001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  11002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  11003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  11004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  11005 (vector dim =  2000 )
#   y vector for this sequence  11006 : (vector dim =  2000 )
# new sequence:  12000
#    1 th vector for this sequence. Sentence  12000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  12001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  12002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  12003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  12004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  12005 (vector dim =  2000 )
#   y vector for this sequence  12006 : (vector dim =  2000 )
# new sequence:  13000
#    1 th vector for this sequence. Sentence  13000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  13001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  13002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  13003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  13004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  13005 (vector dim =  2000 )
#   y vector for this sequence  13006 : (vector dim =  2000 )
# new sequence:  14000
#    1 th vector for this sequence. Sentence  14000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  14001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  14002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  14003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  14004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  14005 (vector dim =  2000 )
#   y vector for this sequence  14006 : (vector dim =  2000 )
# new sequence:  15000
#    1 th vector for this sequence. Sentence  15000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  15001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  15002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  15003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  15004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  15005 (vector dim =  2000 )
#   y vector for this sequence  15006 : (vector dim =  2000 )
# new sequence:  16000
#    1 th vector for this sequence. Sentence  16000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  16001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  16002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  16003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  16004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  16005 (vector dim =  2000 )
#   y vector for this sequence  16006 : (vector dim =  2000 )
# new sequence:  17000
#    1 th vector for this sequence. Sentence  17000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  17001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  17002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  17003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  17004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  17005 (vector dim =  2000 )
#   y vector for this sequence  17006 : (vector dim =  2000 )
# new sequence:  18000
#    1 th vector for this sequence. Sentence  18000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  18001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  18002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  18003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  18004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  18005 (vector dim =  2000 )
#   y vector for this sequence  18006 : (vector dim =  2000 )
# new sequence:  19000
#    1 th vector for this sequence. Sentence  19000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  19001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  19002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  19003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  19004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  19005 (vector dim =  2000 )
#   y vector for this sequence  19006 : (vector dim =  2000 )
# new sequence:  20000
#    1 th vector for this sequence. Sentence  20000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  20001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  20002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  20003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  20004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  20005 (vector dim =  2000 )
#   y vector for this sequence  20006 : (vector dim =  2000 )
# new sequence:  21000
#    1 th vector for this sequence. Sentence  21000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  21001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  21002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  21003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  21004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  21005 (vector dim =  2000 )
#   y vector for this sequence  21006 : (vector dim =  2000 )
# new sequence:  22000
#    1 th vector for this sequence. Sentence  22000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  22001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  22002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  22003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  22004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  22005 (vector dim =  2000 )
#   y vector for this sequence  22006 : (vector dim =  2000 )
# new sequence:  23000
#    1 th vector for this sequence. Sentence  23000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  23001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  23002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  23003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  23004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  23005 (vector dim =  2000 )
#   y vector for this sequence  23006 : (vector dim =  2000 )
# new sequence:  24000
#    1 th vector for this sequence. Sentence  24000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  24001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  24002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  24003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  24004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  24005 (vector dim =  2000 )
#   y vector for this sequence  24006 : (vector dim =  2000 )
# new sequence:  25000
#    1 th vector for this sequence. Sentence  25000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  25001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  25002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  25003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  25004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  25005 (vector dim =  2000 )
#   y vector for this sequence  25006 : (vector dim =  2000 )
# new sequence:  26000
#    1 th vector for this sequence. Sentence  26000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  26001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  26002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  26003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  26004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  26005 (vector dim =  2000 )
#   y vector for this sequence  26006 : (vector dim =  2000 )
# new sequence:  27000
#    1 th vector for this sequence. Sentence  27000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  27001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  27002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  27003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  27004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  27005 (vector dim =  2000 )
#   y vector for this sequence  27006 : (vector dim =  2000 )
# new sequence:  28000
#    1 th vector for this sequence. Sentence  28000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  28001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  28002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  28003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  28004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  28005 (vector dim =  2000 )
#   y vector for this sequence  28006 : (vector dim =  2000 )
# new sequence:  29000
#    1 th vector for this sequence. Sentence  29000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  29001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  29002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  29003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  29004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  29005 (vector dim =  2000 )
#   y vector for this sequence  29006 : (vector dim =  2000 )
# new sequence:  30000
#    1 th vector for this sequence. Sentence  30000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  30001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  30002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  30003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  30004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  30005 (vector dim =  2000 )
#   y vector for this sequence  30006 : (vector dim =  2000 )
# new sequence:  31000
#    1 th vector for this sequence. Sentence  31000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  31001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  31002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  31003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  31004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  31005 (vector dim =  2000 )
#   y vector for this sequence  31006 : (vector dim =  2000 )
# new sequence:  32000
#    1 th vector for this sequence. Sentence  32000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  32001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  32002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  32003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  32004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  32005 (vector dim =  2000 )
#   y vector for this sequence  32006 : (vector dim =  2000 )
# new sequence:  33000
#    1 th vector for this sequence. Sentence  33000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  33001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  33002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  33003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  33004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  33005 (vector dim =  2000 )
#   y vector for this sequence  33006 : (vector dim =  2000 )
# new sequence:  34000
#    1 th vector for this sequence. Sentence  34000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  34001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  34002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  34003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  34004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  34005 (vector dim =  2000 )
#   y vector for this sequence  34006 : (vector dim =  2000 )
# new sequence:  35000
#    1 th vector for this sequence. Sentence  35000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  35001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  35002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  35003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  35004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  35005 (vector dim =  2000 )
#   y vector for this sequence  35006 : (vector dim =  2000 )
# new sequence:  36000
#    1 th vector for this sequence. Sentence  36000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  36001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  36002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  36003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  36004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  36005 (vector dim =  2000 )
#   y vector for this sequence  36006 : (vector dim =  2000 )
# new sequence:  37000
#    1 th vector for this sequence. Sentence  37000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  37001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  37002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  37003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  37004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  37005 (vector dim =  2000 )
#   y vector for this sequence  37006 : (vector dim =  2000 )
# new sequence:  38000
#    1 th vector for this sequence. Sentence  38000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  38001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  38002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  38003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  38004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  38005 (vector dim =  2000 )
#   y vector for this sequence  38006 : (vector dim =  2000 )
# new sequence:  39000
#    1 th vector for this sequence. Sentence  39000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  39001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  39002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  39003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  39004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  39005 (vector dim =  2000 )
#   y vector for this sequence  39006 : (vector dim =  2000 )
# new sequence:  40000
#    1 th vector for this sequence. Sentence  40000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  40001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  40002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  40003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  40004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  40005 (vector dim =  2000 )
#   y vector for this sequence  40006 : (vector dim =  2000 )
# new sequence:  41000
#    1 th vector for this sequence. Sentence  41000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  41001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  41002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  41003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  41004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  41005 (vector dim =  2000 )
#   y vector for this sequence  41006 : (vector dim =  2000 )
# new sequence:  42000
#    1 th vector for this sequence. Sentence  42000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  42001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  42002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  42003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  42004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  42005 (vector dim =  2000 )
#   y vector for this sequence  42006 : (vector dim =  2000 )
# new sequence:  43000
#    1 th vector for this sequence. Sentence  43000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  43001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  43002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  43003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  43004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  43005 (vector dim =  2000 )
#   y vector for this sequence  43006 : (vector dim =  2000 )
# new sequence:  44000
#    1 th vector for this sequence. Sentence  44000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  44001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  44002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  44003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  44004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  44005 (vector dim =  2000 )
#   y vector for this sequence  44006 : (vector dim =  2000 )
# new sequence:  45000
#    1 th vector for this sequence. Sentence  45000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  45001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  45002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  45003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  45004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  45005 (vector dim =  2000 )
#   y vector for this sequence  45006 : (vector dim =  2000 )
# new sequence:  46000
#    1 th vector for this sequence. Sentence  46000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  46001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  46002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  46003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  46004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  46005 (vector dim =  2000 )
#   y vector for this sequence  46006 : (vector dim =  2000 )
# new sequence:  47000
#    1 th vector for this sequence. Sentence  47000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  47001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  47002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  47003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  47004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  47005 (vector dim =  2000 )
#   y vector for this sequence  47006 : (vector dim =  2000 )
# new sequence:  48000
#    1 th vector for this sequence. Sentence  48000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  48001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  48002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  48003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  48004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  48005 (vector dim =  2000 )
#   y vector for this sequence  48006 : (vector dim =  2000 )
# new sequence:  49000
#    1 th vector for this sequence. Sentence  49000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  49001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  49002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  49003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  49004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  49005 (vector dim =  2000 )
#   y vector for this sequence  49006 : (vector dim =  2000 )
# new sequence:  50000
#    1 th vector for this sequence. Sentence  50000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  50001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  50002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  50003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  50004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  50005 (vector dim =  2000 )
#   y vector for this sequence  50006 : (vector dim =  2000 )
# new sequence:  51000
#    1 th vector for this sequence. Sentence  51000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  51001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  51002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  51003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  51004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  51005 (vector dim =  2000 )
#   y vector for this sequence  51006 : (vector dim =  2000 )
# new sequence:  52000
#    1 th vector for this sequence. Sentence  52000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  52001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  52002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  52003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  52004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  52005 (vector dim =  2000 )
#   y vector for this sequence  52006 : (vector dim =  2000 )
# new sequence:  53000
#    1 th vector for this sequence. Sentence  53000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  53001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  53002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  53003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  53004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  53005 (vector dim =  2000 )
#   y vector for this sequence  53006 : (vector dim =  2000 )
# new sequence:  54000
#    1 th vector for this sequence. Sentence  54000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  54001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  54002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  54003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  54004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  54005 (vector dim =  2000 )
#   y vector for this sequence  54006 : (vector dim =  2000 )
# new sequence:  55000
#    1 th vector for this sequence. Sentence  55000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  55001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  55002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  55003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  55004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  55005 (vector dim =  2000 )
#   y vector for this sequence  55006 : (vector dim =  2000 )
# new sequence:  56000
#    1 th vector for this sequence. Sentence  56000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  56001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  56002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  56003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  56004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  56005 (vector dim =  2000 )
#   y vector for this sequence  56006 : (vector dim =  2000 )
# new sequence:  57000
#    1 th vector for this sequence. Sentence  57000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  57001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  57002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  57003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  57004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  57005 (vector dim =  2000 )
#   y vector for this sequence  57006 : (vector dim =  2000 )
# new sequence:  58000
#    1 th vector for this sequence. Sentence  58000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  58001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  58002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  58003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  58004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  58005 (vector dim =  2000 )
#   y vector for this sequence  58006 : (vector dim =  2000 )
# new sequence:  59000
#    1 th vector for this sequence. Sentence  59000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  59001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  59002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  59003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  59004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  59005 (vector dim =  2000 )
#   y vector for this sequence  59006 : (vector dim =  2000 )
# new sequence:  60000
#    1 th vector for this sequence. Sentence  60000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  60001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  60002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  60003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  60004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  60005 (vector dim =  2000 )
#   y vector for this sequence  60006 : (vector dim =  2000 )
# new sequence:  61000
#    1 th vector for this sequence. Sentence  61000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  61001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  61002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  61003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  61004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  61005 (vector dim =  2000 )
#   y vector for this sequence  61006 : (vector dim =  2000 )
# new sequence:  62000
#    1 th vector for this sequence. Sentence  62000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  62001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  62002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  62003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  62004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  62005 (vector dim =  2000 )
#   y vector for this sequence  62006 : (vector dim =  2000 )
# new sequence:  63000
#    1 th vector for this sequence. Sentence  63000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  63001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  63002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  63003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  63004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  63005 (vector dim =  2000 )
#   y vector for this sequence  63006 : (vector dim =  2000 )
# new sequence:  64000
#    1 th vector for this sequence. Sentence  64000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  64001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  64002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  64003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  64004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  64005 (vector dim =  2000 )
#   y vector for this sequence  64006 : (vector dim =  2000 )
# new sequence:  65000
#    1 th vector for this sequence. Sentence  65000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  65001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  65002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  65003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  65004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  65005 (vector dim =  2000 )
#   y vector for this sequence  65006 : (vector dim =  2000 )
# new sequence:  66000
#    1 th vector for this sequence. Sentence  66000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  66001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  66002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  66003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  66004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  66005 (vector dim =  2000 )
#   y vector for this sequence  66006 : (vector dim =  2000 )
# new sequence:  67000
#    1 th vector for this sequence. Sentence  67000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  67001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  67002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  67003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  67004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  67005 (vector dim =  2000 )
#   y vector for this sequence  67006 : (vector dim =  2000 )
# new sequence:  68000
#    1 th vector for this sequence. Sentence  68000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  68001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  68002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  68003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  68004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  68005 (vector dim =  2000 )
#   y vector for this sequence  68006 : (vector dim =  2000 )
# new sequence:  69000
#    1 th vector for this sequence. Sentence  69000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  69001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  69002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  69003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  69004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  69005 (vector dim =  2000 )
#   y vector for this sequence  69006 : (vector dim =  2000 )
# new sequence:  70000
#    1 th vector for this sequence. Sentence  70000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  70001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  70002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  70003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  70004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  70005 (vector dim =  2000 )
#   y vector for this sequence  70006 : (vector dim =  2000 )
# new sequence:  71000
#    1 th vector for this sequence. Sentence  71000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  71001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  71002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  71003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  71004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  71005 (vector dim =  2000 )
#   y vector for this sequence  71006 : (vector dim =  2000 )
# new sequence:  72000
#    1 th vector for this sequence. Sentence  72000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  72001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  72002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  72003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  72004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  72005 (vector dim =  2000 )
#   y vector for this sequence  72006 : (vector dim =  2000 )
# new sequence:  73000
#    1 th vector for this sequence. Sentence  73000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  73001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  73002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  73003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  73004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  73005 (vector dim =  2000 )
#   y vector for this sequence  73006 : (vector dim =  2000 )
# new sequence:  74000
#    1 th vector for this sequence. Sentence  74000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  74001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  74002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  74003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  74004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  74005 (vector dim =  2000 )
#   y vector for this sequence  74006 : (vector dim =  2000 )
# new sequence:  75000
#    1 th vector for this sequence. Sentence  75000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  75001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  75002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  75003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  75004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  75005 (vector dim =  2000 )
#   y vector for this sequence  75006 : (vector dim =  2000 )
# new sequence:  76000
#    1 th vector for this sequence. Sentence  76000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  76001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  76002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  76003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  76004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  76005 (vector dim =  2000 )
#   y vector for this sequence  76006 : (vector dim =  2000 )
# new sequence:  77000
#    1 th vector for this sequence. Sentence  77000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  77001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  77002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  77003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  77004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  77005 (vector dim =  2000 )
#   y vector for this sequence  77006 : (vector dim =  2000 )
# new sequence:  78000
#    1 th vector for this sequence. Sentence  78000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  78001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  78002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  78003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  78004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  78005 (vector dim =  2000 )
#   y vector for this sequence  78006 : (vector dim =  2000 )
# new sequence:  79000
#    1 th vector for this sequence. Sentence  79000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  79001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  79002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  79003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  79004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  79005 (vector dim =  2000 )
#   y vector for this sequence  79006 : (vector dim =  2000 )
# new sequence:  80000
#    1 th vector for this sequence. Sentence  80000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  80001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  80002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  80003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  80004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  80005 (vector dim =  2000 )
#   y vector for this sequence  80006 : (vector dim =  2000 )
# new sequence:  81000
#    1 th vector for this sequence. Sentence  81000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  81001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  81002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  81003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  81004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  81005 (vector dim =  2000 )
#   y vector for this sequence  81006 : (vector dim =  2000 )
# new sequence:  82000
#    1 th vector for this sequence. Sentence  82000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  82001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  82002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  82003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  82004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  82005 (vector dim =  2000 )
#   y vector for this sequence  82006 : (vector dim =  2000 )
# new sequence:  83000
#    1 th vector for this sequence. Sentence  83000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  83001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  83002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  83003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  83004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  83005 (vector dim =  2000 )
#   y vector for this sequence  83006 : (vector dim =  2000 )
# new sequence:  84000
#    1 th vector for this sequence. Sentence  84000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  84001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  84002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  84003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  84004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  84005 (vector dim =  2000 )
#   y vector for this sequence  84006 : (vector dim =  2000 )
# new sequence:  85000
#    1 th vector for this sequence. Sentence  85000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  85001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  85002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  85003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  85004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  85005 (vector dim =  2000 )
#   y vector for this sequence  85006 : (vector dim =  2000 )
# new sequence:  86000
#    1 th vector for this sequence. Sentence  86000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  86001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  86002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  86003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  86004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  86005 (vector dim =  2000 )
#   y vector for this sequence  86006 : (vector dim =  2000 )
# new sequence:  87000
#    1 th vector for this sequence. Sentence  87000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  87001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  87002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  87003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  87004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  87005 (vector dim =  2000 )
#   y vector for this sequence  87006 : (vector dim =  2000 )
# new sequence:  88000
#    1 th vector for this sequence. Sentence  88000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  88001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  88002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  88003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  88004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  88005 (vector dim =  2000 )
#   y vector for this sequence  88006 : (vector dim =  2000 )
# new sequence:  89000
#    1 th vector for this sequence. Sentence  89000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  89001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  89002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  89003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  89004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  89005 (vector dim =  2000 )
#   y vector for this sequence  89006 : (vector dim =  2000 )
# new sequence:  90000
#    1 th vector for this sequence. Sentence  90000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  90001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  90002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  90003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  90004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  90005 (vector dim =  2000 )
#   y vector for this sequence  90006 : (vector dim =  2000 )
# new sequence:  91000
#    1 th vector for this sequence. Sentence  91000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  91001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  91002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  91003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  91004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  91005 (vector dim =  2000 )
#   y vector for this sequence  91006 : (vector dim =  2000 )
# new sequence:  92000
#    1 th vector for this sequence. Sentence  92000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  92001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  92002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  92003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  92004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  92005 (vector dim =  2000 )
#   y vector for this sequence  92006 : (vector dim =  2000 )
# new sequence:  93000
#    1 th vector for this sequence. Sentence  93000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  93001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  93002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  93003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  93004 (vector dim =  2000 )
# ...
#    4 th vector for this sequence. Sentence  455003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  455004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  455005 (vector dim =  2000 )
#   y vector for this sequence  455006 : (vector dim =  2000 )
# new sequence:  456000
#    1 th vector for this sequence. Sentence  456000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  456001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  456002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  456003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  456004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  456005 (vector dim =  2000 )
#   y vector for this sequence  456006 : (vector dim =  2000 )
# new sequence:  457000
#    1 th vector for this sequence. Sentence  457000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  457001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  457002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  457003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  457004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  457005 (vector dim =  2000 )
#   y vector for this sequence  457006 : (vector dim =  2000 )
# new sequence:  458000
#    1 th vector for this sequence. Sentence  458000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  458001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  458002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  458003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  458004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  458005 (vector dim =  2000 )
#   y vector for this sequence  458006 : (vector dim =  2000 )
# new sequence:  459000
#    1 th vector for this sequence. Sentence  459000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  459001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  459002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  459003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  459004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  459005 (vector dim =  2000 )
#   y vector for this sequence  459006 : (vector dim =  2000 )
# new sequence:  460000
#    1 th vector for this sequence. Sentence  460000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  460001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  460002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  460003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  460004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  460005 (vector dim =  2000 )
#   y vector for this sequence  460006 : (vector dim =  2000 )
# new sequence:  461000
#    1 th vector for this sequence. Sentence  461000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  461001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  461002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  461003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  461004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  461005 (vector dim =  2000 )
#   y vector for this sequence  461006 : (vector dim =  2000 )
# new sequence:  462000
#    1 th vector for this sequence. Sentence  462000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  462001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  462002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  462003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  462004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  462005 (vector dim =  2000 )
#   y vector for this sequence  462006 : (vector dim =  2000 )
# new sequence:  463000
#    1 th vector for this sequence. Sentence  463000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  463001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  463002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  463003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  463004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  463005 (vector dim =  2000 )
#   y vector for this sequence  463006 : (vector dim =  2000 )
# new sequence:  464000
#    1 th vector for this sequence. Sentence  464000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  464001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  464002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  464003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  464004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  464005 (vector dim =  2000 )
#   y vector for this sequence  464006 : (vector dim =  2000 )
# new sequence:  465000
#    1 th vector for this sequence. Sentence  465000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  465001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  465002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  465003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  465004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  465005 (vector dim =  2000 )
#   y vector for this sequence  465006 : (vector dim =  2000 )
# new sequence:  466000
#    1 th vector for this sequence. Sentence  466000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  466001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  466002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  466003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  466004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  466005 (vector dim =  2000 )
#   y vector for this sequence  466006 : (vector dim =  2000 )
# new sequence:  467000
#    1 th vector for this sequence. Sentence  467000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  467001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  467002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  467003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  467004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  467005 (vector dim =  2000 )
#   y vector for this sequence  467006 : (vector dim =  2000 )
# new sequence:  468000
#    1 th vector for this sequence. Sentence  468000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  468001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  468002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  468003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  468004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  468005 (vector dim =  2000 )
#   y vector for this sequence  468006 : (vector dim =  2000 )
# new sequence:  469000
#    1 th vector for this sequence. Sentence  469000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  469001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  469002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  469003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  469004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  469005 (vector dim =  2000 )
#   y vector for this sequence  469006 : (vector dim =  2000 )
# new sequence:  470000
#    1 th vector for this sequence. Sentence  470000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  470001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  470002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  470003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  470004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  470005 (vector dim =  2000 )
#   y vector for this sequence  470006 : (vector dim =  2000 )
# new sequence:  471000
#    1 th vector for this sequence. Sentence  471000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  471001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  471002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  471003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  471004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  471005 (vector dim =  2000 )
#   y vector for this sequence  471006 : (vector dim =  2000 )
# new sequence:  472000
#    1 th vector for this sequence. Sentence  472000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  472001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  472002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  472003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  472004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  472005 (vector dim =  2000 )
#   y vector for this sequence  472006 : (vector dim =  2000 )
# new sequence:  473000
#    1 th vector for this sequence. Sentence  473000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  473001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  473002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  473003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  473004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  473005 (vector dim =  2000 )
#   y vector for this sequence  473006 : (vector dim =  2000 )
# new sequence:  474000
#    1 th vector for this sequence. Sentence  474000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  474001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  474002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  474003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  474004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  474005 (vector dim =  2000 )
#   y vector for this sequence  474006 : (vector dim =  2000 )
# new sequence:  475000
#    1 th vector for this sequence. Sentence  475000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  475001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  475002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  475003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  475004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  475005 (vector dim =  2000 )
#   y vector for this sequence  475006 : (vector dim =  2000 )
# new sequence:  476000
#    1 th vector for this sequence. Sentence  476000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  476001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  476002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  476003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  476004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  476005 (vector dim =  2000 )
#   y vector for this sequence  476006 : (vector dim =  2000 )
# new sequence:  477000
#    1 th vector for this sequence. Sentence  477000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  477001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  477002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  477003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  477004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  477005 (vector dim =  2000 )
#   y vector for this sequence  477006 : (vector dim =  2000 )
# new sequence:  478000
#    1 th vector for this sequence. Sentence  478000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  478001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  478002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  478003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  478004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  478005 (vector dim =  2000 )
#   y vector for this sequence  478006 : (vector dim =  2000 )
# new sequence:  479000
#    1 th vector for this sequence. Sentence  479000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  479001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  479002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  479003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  479004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  479005 (vector dim =  2000 )
#   y vector for this sequence  479006 : (vector dim =  2000 )
# new sequence:  480000
#    1 th vector for this sequence. Sentence  480000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  480001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  480002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  480003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  480004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  480005 (vector dim =  2000 )
#   y vector for this sequence  480006 : (vector dim =  2000 )
# new sequence:  481000
#    1 th vector for this sequence. Sentence  481000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  481001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  481002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  481003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  481004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  481005 (vector dim =  2000 )
#   y vector for this sequence  481006 : (vector dim =  2000 )
# new sequence:  482000
#    1 th vector for this sequence. Sentence  482000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  482001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  482002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  482003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  482004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  482005 (vector dim =  2000 )
#   y vector for this sequence  482006 : (vector dim =  2000 )
# new sequence:  483000
#    1 th vector for this sequence. Sentence  483000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  483001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  483002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  483003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  483004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  483005 (vector dim =  2000 )
#   y vector for this sequence  483006 : (vector dim =  2000 )
# new sequence:  484000
#    1 th vector for this sequence. Sentence  484000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  484001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  484002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  484003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  484004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  484005 (vector dim =  2000 )
#   y vector for this sequence  484006 : (vector dim =  2000 )
# new sequence:  485000
#    1 th vector for this sequence. Sentence  485000 (vector dim =  2000 )
#    2 th vector for this sequence. Sentence  485001 (vector dim =  2000 )
#    3 th vector for this sequence. Sentence  485002 (vector dim =  2000 )
#    4 th vector for this sequence. Sentence  485003 (vector dim =  2000 )
#    5 th vector for this sequence. Sentence  485004 (vector dim =  2000 )
#    6 th vector for this sequence. Sentence  485005 (vector dim =  2000 )
#   y vector for this sequence  485006 : (vector dim =  2000 )
# (485604, 6, 2000) (485604, 2000)

# %%
from __future__ import print_function
from keras import regularizers
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout, Embedding, Flatten, Bidirectional, Input, LSTM
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.optimizers import Adam
from keras.metrics import categorical_accuracy, mean_squared_error, mean_absolute_error
from keras.losses import logcosh

def bidirectional_lstm_model(seq_length, vector_dim):
    print('Building LSTM model...')
    model = Sequential()
    model.add(Bidirectional(LSTM(rnn_size, activation="relu"),input_shape=(seq_length, vector_dim)))
    model.add(Dropout(0.5))
    model.add(Dense(vector_dim))
    
    optimizer = Adam(lr=learning_rate)
    callbacks=[EarlyStopping(patience=2, monitor='val_loss')]
    model.compile(loss='logcosh', optimizer=optimizer, metrics=['acc'])
    print('LSTM model built.')
    return model

# %%
rnn_size = 32 # size of RNN
# vector_dim = 500
learning_rate = 0.0001 #learning rate

model_sequence = bidirectional_lstm_model(n_sequenced_lines, v_dim)
# Out:
# Building LSTM model...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# LSTM model built.

# %%
batch_size = 30 # minibatch size

callbacks=[EarlyStopping(patience=3, monitor='val_loss'),
           ModelCheckpoint(filepath='line_sequence_lstm.{epoch:02d}.hdf5',\
                           monitor='val_loss', verbose=1, mode='auto', save_freq=1000)]

history = model_sequence.fit(X_train, y_train,
                 batch_size=batch_size,
                 shuffle=True,
                 epochs=40,
                 callbacks=callbacks,
                 validation_split=0.1)

#save the model
model_sequence.save('line_sequence_lstm.final.hdf5')
# Out:
# Epoch 1/40
#   998/14569 [=>............................] - ETA: 4:56 - loss: 5.2908e-04 - acc: 0.3345
# Epoch 00001: saving model to line_sequence_lstm.01.hdf5
#  1999/14569 [===>..........................] - ETA: 4:33 - loss: 5.2704e-04 - acc: 0.3310
# Epoch 00001: saving model to line_sequence_lstm.01.hdf5
#  2999/14569 [=====>........................] - ETA: 4:10 - loss: 5.2353e-04 - acc: 0.3319
# Epoch 00001: saving model to line_sequence_lstm.01.hdf5
#  3998/14569 [=======>......................] - ETA: 3:49 - loss: 5.2338e-04 - acc: 0.3333
# Epoch 00001: saving model to line_sequence_lstm.01.hdf5
#  4999/14569 [=========>....................] - ETA: 3:27 - loss: 5.2291e-04 - acc: 0.3334
# Epoch 00001: saving model to line_sequence_lstm.01.hdf5
#  5999/14569 [===========>..................] - ETA: 3:05 - loss: 5.2312e-04 - acc: 0.3348
# Epoch 00001: saving model to line_sequence_lstm.01.hdf5
#  6999/14569 [=============>................] - ETA: 2:44 - loss: 5.2381e-04 - acc: 0.3344
# Epoch 00001: saving model to line_sequence_lstm.01.hdf5
#  7999/14569 [===============>..............] - ETA: 2:22 - loss: 5.2312e-04 - acc: 0.3343
# Epoch 00001: saving model to line_sequence_lstm.01.hdf5
